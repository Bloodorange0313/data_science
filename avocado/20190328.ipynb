# %%
# First step, import libraries and then dataset
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("avocado.csv")
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
df.replace("?", np.nan, inplace = True)
no_data = df.isnull()
for column in no_data.columns.values.tolist():
    print(column)
    print (no_data[column].value_counts())
    print("")
# Out:
# Unnamed: 0
# False    18249
# Name: Unnamed: 0, dtype: int64
#
# Date
# False    18249
# Name: Date, dtype: int64
#
# AveragePrice
# False    18249
# Name: AveragePrice, dtype: int64
#
# Total Volume
# False    18249
# Name: Total Volume, dtype: int64
#
# 4046
# False    18249
# Name: 4046, dtype: int64
#
# 4225
# False    18249
# Name: 4225, dtype: int64
#
# 4770
# False    18249
# Name: 4770, dtype: int64
#
# Total Bags
# False    18249
# Name: Total Bags, dtype: int64
#
# Small Bags
# False    18249
# Name: Small Bags, dtype: int64
#
# Large Bags
# False    18249
# Name: Large Bags, dtype: int64
#
# XLarge Bags
# False    18249
# Name: XLarge Bags, dtype: int64
#
# type
# False    18249
# Name: type, dtype: int64
#
# year
# False    18249
# Name: year, dtype: int64
#
# region
# False    18249
# Name: region, dtype: int64

# %%
print(df.shape)
# Out:
# (18249, 14)

# %%
df.dropna(inplace=True)
df.shape
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume       4046  \
# 0               0  2015-12-27          1.33      64236.62    1036.74
# 1               1  2015-12-20          1.35      54876.98     674.28
# 2               2  2015-12-13          0.93     118220.22     794.70
# 3               3  2015-12-06          1.08      78992.15    1132.00
# 4               4  2015-11-29          1.28      51039.60     941.48
# 5               5  2015-11-22          1.26      55979.78    1184.27
# 6               6  2015-11-15          0.99      83453.76    1368.92
# 7               7  2015-11-08          0.98     109428.33     703.75
# 8               8  2015-11-01          1.02      99811.42    1022.15
# 9               9  2015-10-25          1.07      74338.76     842.40
# 10             10  2015-10-18          1.12      84843.44     924.86
# 11             11  2015-10-11          1.28      64489.17    1582.03
# 12             12  2015-10-04          1.31      61007.10    2268.32
# ...

# %%
df = df.drop("Unnamed: 0", axis = 1)
df
# Out:
#              Date  AveragePrice  Total Volume       4046       4225     4770  \
# 0      2015-12-27          1.33      64236.62    1036.74   54454.85    48.16
# 1      2015-12-20          1.35      54876.98     674.28   44638.81    58.33
# 2      2015-12-13          0.93     118220.22     794.70  109149.67   130.50
# 3      2015-12-06          1.08      78992.15    1132.00   71976.41    72.58
# 4      2015-11-29          1.28      51039.60     941.48   43838.39    75.78
# 5      2015-11-22          1.26      55979.78    1184.27   48067.99    43.61
# 6      2015-11-15          0.99      83453.76    1368.92   73672.72    93.26
# 7      2015-11-08          0.98     109428.33     703.75  101815.36    80.00
# 8      2015-11-01          1.02      99811.42    1022.15   87315.57    85.34
# 9      2015-10-25          1.07      74338.76     842.40   64757.44   113.00
# 10     2015-10-18          1.12      84843.44     924.86   75595.85   117.07
# ...

# %%
type(df.loc[0, 'Date'])
# Out:
# str

# %%
print(pd.to_datetime(df['Date']))
# Out:
# 0       2015-12-27
# 1       2015-12-20
# 2       2015-12-13
# 3       2015-12-06
# 4       2015-11-29
# 5       2015-11-22
# 6       2015-11-15
# 7       2015-11-08
# 8       2015-11-01
# 9       2015-10-25
# 10      2015-10-18
# 11      2015-10-11
# 12      2015-10-04
# 13      2015-09-27
# 14      2015-09-20
# 15      2015-09-13
# 16      2015-09-06
# 17      2015-08-30
# 18      2015-08-23
# 19      2015-08-16
# 20      2015-08-09
# 21      2015-08-02
# 22      2015-07-26
# 23      2015-07-19
# 24      2015-07-12
# 25      2015-07-05
# 26      2015-06-28
# 27      2015-06-21
# 28      2015-06-14
# 29      2015-06-07
#            ...
# 18219   2018-02-11
# 18220   2018-02-04
# 18221   2018-01-28
# 18222   2018-01-21
# 18223   2018-01-14
# 18224   2018-01-07
# 18225   2018-03-25
# 18226   2018-03-18
# 18227   2018-03-11
# 18228   2018-03-04
# 18229   2018-02-25
# 18230   2018-02-18
# 18231   2018-02-11
# 18232   2018-02-04
# 18233   2018-01-28
# 18234   2018-01-21
# ...

# %%
df_s = df.sort_values('Date')
df_s
# Out:
#              Date  AveragePrice  Total Volume         4046         4225  \
# 11569  2015-01-04          1.75      27365.89      9307.34      3844.81
# 9593   2015-01-04          1.49      17723.17      1189.35     15628.27
# 10009  2015-01-04          1.68       2896.72       161.68       206.96
# 1819   2015-01-04          1.52      54956.80      3013.04     35456.88
# 9333   2015-01-04          1.64       1505.12         1.27      1129.50
# 2807   2015-01-04          0.75     758118.95    426878.87    147958.43
# 1195   2015-01-04          0.85    2682159.95   1837999.65    524430.47
# 10269  2015-01-04          1.50       6329.83      3730.80      2141.91
# 103    2015-01-04          1.00     435021.49    364302.39     23821.16
# 1143   2015-01-04          0.80     317861.35    134003.07    120628.37
# 623    2015-01-04          0.74    1086363.97    612795.80    374420.68
# 10425  2015-01-04          1.82       2288.44      1438.04        53.73
# ...

# %%
#df.query('state == "CA"')
df_s2 = df_s.query('region ==  "Southeast" and type == "organic"')
df_s2
# Out:
#              Date  AveragePrice  Total Volume      4046      4225     4770  \
# 11569  2015-01-04          1.75      27365.89   9307.34   3844.81   615.28
# 11568  2015-01-11          1.83      23690.65  10166.46   4678.19   524.42
# 11567  2015-01-18          1.79      25740.00  10781.05   3489.26   498.66
# 11566  2015-01-25          1.81      23809.30   9855.11   3187.02   612.99
# 11565  2015-02-01          1.60      35085.70   8698.27   9368.82   804.65
# 11564  2015-02-08          1.51      50546.78  10197.75  16658.11   792.54
# 11563  2015-02-15          1.64      31775.03   9542.72  10814.64   666.44
# 11562  2015-02-22          1.59      37584.04  10316.90  15076.29   586.36
# 11561  2015-03-01          1.46      47299.44   9547.92  20649.03   728.08
# 11560  2015-03-08          1.47      46965.06  10517.69  19351.28   802.40
# 11559  2015-03-15          1.48      44030.34  11716.79  17032.10   804.88
# ...

# %%
df = df_s2.set_index('Date')

# %%
#print(pd.to_datetime(df_s['Date']))
plt.figure(figsize=(60,40))

plt.plot(df.index, df_s2['AveragePrice'])
plt.xticks(rotation=100)

#plt.xlim('2018-01-28','2018-03-25' )
plt.show()
